# %% [markdown]
# # Business & Data Understanding
#
# Objetivos:
# - Entender o negócio e objetivos do IDS
# - Conhecer o dataset IoT Intrusion Detection
# - Realizar EDA inicial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ajuste o caminho do dataset conforme necessário
df = pd.read_csv('../archive/final_dataset.csv')
df.head()
